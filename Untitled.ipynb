# %%
from numpy import *
from matplotlib import pyplot as plt
y=[];zmax=50

plt.title('increasing density')
def f(z):
    low=1;G=1;a=1
    return 2*pi*low*G*((a**2+z**2)**(1/2)-z)
plt.plot([i for i in range(imax)],[f(z) for z in range(imax)])
plt.xlabel('height');plt.ylabel('potentiel')

def f(z):
    low=2;G=1;a=1
    return 2*pi*low*G*((a**2+z**2)**(1/2)-z)
plt.plot([i for i in range(imax)],[f(z) for z in range(imax)])
plt.xlabel('height');plt.ylabel('potentiel')

def f(z):
    low=3;G=1;a=1
    return 2*pi*low*G*((a**2+z**2)**(1/2)-z)
plt.plot([i for i in range(imax)],[f(z) for z in range(imax)])
plt.xlabel('height');plt.ylabel('potentiel')

def f(z):
    low=4;G=1;a=1
    return 2*pi*low*G*((a**2+z**2)**(1/2)-z)
plt.plot([i for i in range(imax)],[f(z) for z in range(imax)])
plt.xlabel('height');plt.ylabel('potentiel')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       7     low=1;G=1;a=1
#       8     return 2*pi*low*G*((a**2+z**2)**(1/2)-z)
# ----> 9 plt.plot([i for i in range(imax)],[f(z) for z in range(imax)])
#      10 plt.xlabel('height');plt.ylabel('potentiel')
#      12 def f(z):
#
# NameError: name 'imax' is not defined

# %%
def f(low,z):
    low=1;G=1;a=1
    return 2*pi*low*G*((a**2+z**2)**(1/2)-z)
for low in range(1):
    plt.plot([z for z in range(zmax)],[f(low,z) for z in range(zmax)])
    plt.xlabel('height');plt.ylabel('potentiel')

# %%
def f(z):
    low=1;G=1;m=1;a=1
    return 2*pi*m*low*G*z*((a**2+z**2)**(-1/2)-1)

plt.plot([z for z in range(1001)],[f(z) for z in range(1001)])
plt.xlabel('height');plt.ylabel('potentiel')
# Out:
# Text(0, 0.5, 'potentiel')

# %%
[f(z) for z in range(1001)]
# Out:
# [0.0,
#  -1.84030236902122,
#  -6.9465188295265925,
#  -12.888802962061098,
#  -19.037156125934725,
#  -25.25475644189251,
#  -31.501416033764173,
#  -37.76226103683539,
#  -44.03081668183002,
#  -50.30391208587022,
#  -56.5798500181712,
#  -62.857656816577595,
#  -69.13674202001866,
#  -75.4167308995736,
#  -81.69737645321928,
#  -87.97851056412728,
#  -94.260015617957,
#  -100.54180734798592,
#  -106.82382410817095,
#  -113.10601996366253,
#  -119.3883601224432,
#  -125.6708178440113,
#  -131.95337230376688,
#  -138.23600708990668,
#  -144.518709127539,
#  -150.80146789672918,
#  -157.08427485619077,
#  -163.36712301307887,
#  -169.65000659805085,
#  -175.93292081716243,
#  -182.2158616605207,
#  -188.49882575332978,
#  -194.78181023892785,
#  -201.06481268619913,
#  -207.34783101572503,
#  -213.6308634404627,
#  -219.9139084177751,
#  -226.19696461039666,
#  -232.48003085448195,
#  -238.7631061333062,
#  -245.04618955550296,
#  -251.3292803369667,
#  -257.61237778573104,
# ...
